# %%
print("teszt")
# Out:
# teszt

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("acc.csv")

dataTeszt = pd.read_csv("relegion.csv")

dataTeszt.head(10)
# Out:
#   What is your present religion, if any?  \
# 0                               Response
# 1                          None of these
# 2                                Atheist
# 3                             Protestant
# 4                                 Muslim
# 5                          None of these
# 6                          None of these
# 7                          None of these
# 8                             Protestant
# 9                          None of these
#
#                                           Unnamed: 1  \
# 0                                      None of these
# 1                                 Wesleyan Christian
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5  Working on Christianity. Orthodox seemed too c...
# 6                                      Episcopalian
# 7                                     the multiverse
# ...
